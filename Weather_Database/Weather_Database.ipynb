# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
# Import the NumPy module.
import numpy as np
# Import the random module.
import random
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import Google key
from config import g_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the time module.
import time
# Import timeit.
import timeit
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
import gmaps

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | pemba
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | nanortalik
# Processing Record 9 of Set 1 | adrar
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | juneau
# Processing Record 12 of Set 1 | maun
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | lac du bonnet
# Processing Record 16 of Set 1 | touho
# Processing Record 17 of Set 1 | killybegs
# Processing Record 18 of Set 1 | villa maria
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | dakar
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | morwell
# Processing Record 26 of Set 1 | saint anthony
# Processing Record 27 of Set 1 | mwinilunga
# Processing Record 28 of Set 1 | bollnas
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | huarmey
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | kuryk
# Processing Record 35 of Set 1 | mount isa
# Processing Record 36 of Set 1 | isla mujeres
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | rio esteban
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | saquena
# Processing Record 41 of Set 1 | kununurra
# Processing Record 42 of Set 1 | liberal
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | olivenza
# Processing Record 45 of Set 1 | yeppoon
# Processing Record 46 of Set 1 | nabire
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | xiamen
# Processing Record 49 of Set 1 | lasa
# Processing Record 50 of Set 1 | dicabisagan
# Processing Record 1 of Set 2 | la paz
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | onega
# Processing Record 4 of Set 2 | wajima
# Processing Record 5 of Set 2 | capao bonito
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | la palma
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | modakeke
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | hamilton
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | samarai
# Processing Record 14 of Set 2 | almetyevsk
# Processing Record 15 of Set 2 | kieta
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | manokwari
# Processing Record 18 of Set 2 | saint-prosper
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | deqing
# Processing Record 22 of Set 2 | taoudenni
# Processing Record 23 of Set 2 | rio grande
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | kitgum
# Processing Record 26 of Set 2 | barreirinha
# Processing Record 27 of Set 2 | zaysan
# Processing Record 28 of Set 2 | batemans bay
# Processing Record 29 of Set 2 | taksimo
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | nombre de dios
# Processing Record 33 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 2 | lodja
# Processing Record 35 of Set 2 | peterhead
# Processing Record 36 of Set 2 | mbour
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | agirish
# Processing Record 40 of Set 2 | bintulu
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | lieksa
# Processing Record 43 of Set 2 | mugur-aksy
# Processing Record 44 of Set 2 | lebedinyy
# Processing Record 45 of Set 2 | xai-xai
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | saint-augustin
# Processing Record 49 of Set 2 | bayji
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | marrakesh
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | khor
# Processing Record 4 of Set 3 | moron
# Processing Record 5 of Set 3 | kuala selangor
# Processing Record 6 of Set 3 | muravlenko
# Processing Record 7 of Set 3 | quezon
# Processing Record 8 of Set 3 | haizhou
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | gravdal
# Processing Record 12 of Set 3 | lerwick
# Processing Record 13 of Set 3 | kadaya
# Processing Record 14 of Set 3 | ikon-khalk
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | santa catalina
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | barguzin
# Processing Record 26 of Set 3 | hobart
# Processing Record 27 of Set 3 | taburao
# City not found. Skipping...
# Processing Record 28 of Set 3 | kjopsvik
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | itarema
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | yingcheng
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | belyy yar
# Processing Record 37 of Set 3 | saint-pierre
# Processing Record 38 of Set 3 | sao felix do xingu
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | boueni
# Processing Record 41 of Set 3 | port hardy
# Processing Record 42 of Set 3 | gisborne
# Processing Record 43 of Set 3 | nhulunbuy
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | uvat
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | deputatskiy
# Processing Record 48 of Set 3 | ust-nera
# Processing Record 49 of Set 3 | zhigansk
# Processing Record 50 of Set 3 | pogranichnyy
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | jiexiu
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 6 of Set 4 | rzhaksa
# Processing Record 7 of Set 4 | bereda
# Processing Record 8 of Set 4 | pevek
# Processing Record 9 of Set 4 | miri
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | ovalle
# Processing Record 13 of Set 4 | coahuayana
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | axim
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | half moon bay
# Processing Record 18 of Set 4 | eureka
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | luanda
# Processing Record 22 of Set 4 | okhotsk
# Processing Record 23 of Set 4 | berlevag
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | heihe
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | husavik
# Processing Record 28 of Set 4 | los llanos de aridane
# Processing Record 29 of Set 4 | marawi
# Processing Record 30 of Set 4 | matara
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | biak
# Processing Record 33 of Set 4 | launceston
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | kiruna
# Processing Record 36 of Set 4 | chhatak
# Processing Record 37 of Set 4 | jiangdu
# Processing Record 38 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | champerico
# Processing Record 41 of Set 4 | itoman
# Processing Record 42 of Set 4 | teguldet
# Processing Record 43 of Set 4 | vilhena
# Processing Record 44 of Set 4 | chimbarongo
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | hranice
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | wapi pathum
# Processing Record 50 of Set 4 | praya
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | koson
# Processing Record 4 of Set 5 | chara
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | avarua
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | bowen
# Processing Record 13 of Set 5 | yugorsk
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | okato
# Processing Record 16 of Set 5 | macklin
# Processing Record 17 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 5 | pontes e lacerda
# Processing Record 19 of Set 5 | sassandra
# Processing Record 20 of Set 5 | fairmont
# Processing Record 21 of Set 5 | pravia
# Processing Record 22 of Set 5 | wahiawa
# Processing Record 23 of Set 5 | cidreira
# Processing Record 24 of Set 5 | patris
# Processing Record 25 of Set 5 | havre-saint-pierre
# Processing Record 26 of Set 5 | chulym
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | bredasdorp
# Processing Record 29 of Set 5 | chauk
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | san antonio
# Processing Record 32 of Set 5 | lowestoft
# Processing Record 33 of Set 5 | chapais
# Processing Record 34 of Set 5 | bac lieu
# Processing Record 35 of Set 5 | cao bang
# Processing Record 36 of Set 5 | gawler
# Processing Record 37 of Set 5 | durban
# Processing Record 38 of Set 5 | taiyuan
# Processing Record 39 of Set 5 | sayyan
# Processing Record 40 of Set 5 | dhidhdhoo
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | blagoyevo
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | pingtung
# Processing Record 46 of Set 5 | jalu
# Processing Record 47 of Set 5 | alice springs
# Processing Record 48 of Set 5 | college
# Processing Record 49 of Set 5 | kracheh
# City not found. Skipping...
# Processing Record 50 of Set 5 | khorixas
# Processing Record 1 of Set 6 | heze
# Processing Record 2 of Set 6 | gornopravdinsk
# Processing Record 3 of Set 6 | najran
# Processing Record 4 of Set 6 | masvingo
# Processing Record 5 of Set 6 | takoradi
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | lavrentiya
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | bahia honda
# Processing Record 10 of Set 6 | hofn
# Processing Record 11 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 6 | liaoyang
# Processing Record 13 of Set 6 | qasigiannguit
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | ketchikan
# Processing Record 16 of Set 6 | shwebo
# Processing Record 17 of Set 6 | nichinan
# Processing Record 18 of Set 6 | la asuncion
# Processing Record 19 of Set 6 | dunedin
# Processing Record 20 of Set 6 | olafsvik
# Processing Record 21 of Set 6 | jiaojiang
# Processing Record 22 of Set 6 | buchanan
# Processing Record 23 of Set 6 | formiga
# Processing Record 24 of Set 6 | banjar
# Processing Record 25 of Set 6 | zaraza
# Processing Record 26 of Set 6 | mecca
# Processing Record 27 of Set 6 | atambua
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | puerto del rosario
# Processing Record 30 of Set 6 | kyzyl-suu
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | clonakilty
# Processing Record 33 of Set 6 | ouegoa
# Processing Record 34 of Set 6 | aksarka
# Processing Record 35 of Set 6 | havelock
# Processing Record 36 of Set 6 | rawson
# Processing Record 37 of Set 6 | abapo
# Processing Record 38 of Set 6 | muscat
# Processing Record 39 of Set 6 | chazuta
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | karasjok
# Processing Record 42 of Set 6 | marzuq
# Processing Record 43 of Set 6 | kropotkin
# Processing Record 44 of Set 6 | xuanzhou
# Processing Record 45 of Set 6 | carnarvon
# Processing Record 46 of Set 6 | morondava
# Processing Record 47 of Set 6 | tumkur
# Processing Record 48 of Set 6 | dillon
# Processing Record 49 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 6 | berezovyy
# Processing Record 1 of Set 7 | deblin
# Processing Record 2 of Set 7 | arlit
# Processing Record 3 of Set 7 | russell
# Processing Record 4 of Set 7 | salalah
# Processing Record 5 of Set 7 | hunfeld
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | shingu
# Processing Record 9 of Set 7 | mananjary
# Processing Record 10 of Set 7 | udachnyy
# Processing Record 11 of Set 7 | rotterdam
# Processing Record 12 of Set 7 | amapa
# Processing Record 13 of Set 7 | dvinskoy
# Processing Record 14 of Set 7 | dingle
# Processing Record 15 of Set 7 | monrovia
# Processing Record 16 of Set 7 | botou
# Processing Record 17 of Set 7 | riviere-au-renard
# Processing Record 18 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 7 | provideniya
# Processing Record 21 of Set 7 | isabela
# Processing Record 22 of Set 7 | torbay
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | jaisinghnagar
# Processing Record 25 of Set 7 | nipawin
# Processing Record 26 of Set 7 | elizabeth city
# Processing Record 27 of Set 7 | lorengau
# Processing Record 28 of Set 7 | trelew
# Processing Record 29 of Set 7 | port hedland
# Processing Record 30 of Set 7 | leningradskiy
# Processing Record 31 of Set 7 | bijar
# Processing Record 32 of Set 7 | ponta do sol
# Processing Record 33 of Set 7 | narita
# Processing Record 34 of Set 7 | poum
# Processing Record 35 of Set 7 | milkovo
# Processing Record 36 of Set 7 | tobolsk
# Processing Record 37 of Set 7 | mahebourg
# Processing Record 38 of Set 7 | narsaq
# Processing Record 39 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 7 | canutama
# Processing Record 41 of Set 7 | anton lizardo
# Processing Record 42 of Set 7 | halifax
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | kamenka
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | malanje
# Processing Record 47 of Set 7 | whitehorse
# Processing Record 48 of Set 7 | katsuura
# Processing Record 49 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 7 | honiara
# Processing Record 1 of Set 8 | quatre cocos
# Processing Record 2 of Set 8 | cuauhtemoc
# Processing Record 3 of Set 8 | svetlaya
# Processing Record 4 of Set 8 | santo tomas
# Processing Record 5 of Set 8 | salinopolis
# Processing Record 6 of Set 8 | mukhen
# Processing Record 7 of Set 8 | stornoway
# Processing Record 8 of Set 8 | oistins
# Processing Record 9 of Set 8 | teya
# Processing Record 10 of Set 8 | macau
# Processing Record 11 of Set 8 | maputo
# Processing Record 12 of Set 8 | oktyabrskiy
# Processing Record 13 of Set 8 | lindi
# Processing Record 14 of Set 8 | mchinji
# Processing Record 15 of Set 8 | bobrovytsya
# Processing Record 16 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 8 | nabisar
# Processing Record 18 of Set 8 | shelburne
# Processing Record 19 of Set 8 | gazanjyk
# Processing Record 20 of Set 8 | staraya toropa
# Processing Record 21 of Set 8 | bay-khaak
# Processing Record 22 of Set 8 | knysna
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | illapel
# Processing Record 25 of Set 8 | julio de castilhos
# Processing Record 26 of Set 8 | filadelfia
# Processing Record 27 of Set 8 | aracati
# Processing Record 28 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 8 | loxstedt
# Processing Record 30 of Set 8 | lermontovka
# Processing Record 31 of Set 8 | longyan
# Processing Record 32 of Set 8 | zilupe
# Processing Record 33 of Set 8 | yashalta
# Processing Record 34 of Set 8 | kitangari
# Processing Record 35 of Set 8 | chicama
# Processing Record 36 of Set 8 | kloulklubed
# Processing Record 37 of Set 8 | coos bay
# Processing Record 38 of Set 8 | mount gambier
# Processing Record 39 of Set 8 | houma
# Processing Record 40 of Set 8 | marienburg
# Processing Record 41 of Set 8 | ishigaki
# Processing Record 42 of Set 8 | akyab
# Processing Record 43 of Set 8 | sennan
# Processing Record 44 of Set 8 | coihaique
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | asau
# Processing Record 47 of Set 8 | cedar city
# Processing Record 48 of Set 8 | saldanha
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 9 | tongchuan
# Processing Record 2 of Set 9 | kutulik
# Processing Record 3 of Set 9 | platon sanchez
# Processing Record 4 of Set 9 | arraial do cabo
# Processing Record 5 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 9 | ternate
# Processing Record 7 of Set 9 | bubaque
# Processing Record 8 of Set 9 | iralaya
# Processing Record 9 of Set 9 | mola di bari
# Processing Record 10 of Set 9 | shimoda
# Processing Record 11 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 12 of Set 9 | aykhal
# Processing Record 13 of Set 9 | antalaha
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | magdagachi
# Processing Record 16 of Set 9 | henties bay
# Processing Record 17 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 9 | cardston
# Processing Record 19 of Set 9 | ladybrand
# Processing Record 20 of Set 9 | vostok
# Processing Record 21 of Set 9 | baicheng
# Processing Record 22 of Set 9 | acarau
# Processing Record 23 of Set 9 | abaza
# Processing Record 24 of Set 9 | chumikan
# Processing Record 25 of Set 9 | kurumkan
# Processing Record 26 of Set 9 | tungor
# Processing Record 27 of Set 9 | kajaani
# Processing Record 28 of Set 9 | nenjiang
# Processing Record 29 of Set 9 | cockburn town
# Processing Record 30 of Set 9 | dondo
# Processing Record 31 of Set 9 | yatou
# Processing Record 32 of Set 9 | sadovoye
# Processing Record 33 of Set 9 | fairbanks
# Processing Record 34 of Set 9 | san jose
# Processing Record 35 of Set 9 | iqaluit
# Processing Record 36 of Set 9 | mindelo
# Processing Record 37 of Set 9 | mitsamiouli
# Processing Record 38 of Set 9 | mpika
# Processing Record 39 of Set 9 | genhe
# Processing Record 40 of Set 9 | naze
# Processing Record 41 of Set 9 | lichtenburg
# Processing Record 42 of Set 9 | egvekinot
# Processing Record 43 of Set 9 | chagoda
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | vestmanna
# Processing Record 46 of Set 9 | san policarpo
# Processing Record 47 of Set 9 | tura
# Processing Record 48 of Set 9 | verkhnevilyuysk
# Processing Record 49 of Set 9 | pochutla
# Processing Record 50 of Set 9 | henderson
# Processing Record 1 of Set 10 | noumea
# Processing Record 2 of Set 10 | gazli
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | seoul
# Processing Record 5 of Set 10 | meridian
# Processing Record 6 of Set 10 | sisophon
# Processing Record 7 of Set 10 | caibarien
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | belaya gora
# Processing Record 10 of Set 10 | ngong
# Processing Record 11 of Set 10 | saint-georges
# Processing Record 12 of Set 10 | bagdarin
# Processing Record 13 of Set 10 | lima duarte
# Processing Record 14 of Set 10 | chanute
# Processing Record 15 of Set 10 | ust-ilimsk
# Processing Record 16 of Set 10 | sinnamary
# Processing Record 17 of Set 10 | antofagasta
# Processing Record 18 of Set 10 | ambon
# Processing Record 19 of Set 10 | road town
# Processing Record 20 of Set 10 | bonavista
# Processing Record 21 of Set 10 | oranjemund
# Processing Record 22 of Set 10 | kachiry
# Processing Record 23 of Set 10 | geraldton
# Processing Record 24 of Set 10 | eyl
# Processing Record 25 of Set 10 | jinka
# Processing Record 26 of Set 10 | glinka
# Processing Record 27 of Set 10 | daru
# Processing Record 28 of Set 10 | muskogee
# Processing Record 29 of Set 10 | ginir
# Processing Record 30 of Set 10 | kaitangata
# Processing Record 31 of Set 10 | klaeng
# Processing Record 32 of Set 10 | sao filipe
# Processing Record 33 of Set 10 | suluq
# Processing Record 34 of Set 10 | moindou
# Processing Record 35 of Set 10 | las cruces
# Processing Record 36 of Set 10 | ostrovnoy
# Processing Record 37 of Set 10 | umm lajj
# Processing Record 38 of Set 10 | kroderen
# City not found. Skipping...
# Processing Record 39 of Set 10 | urengoy
# Processing Record 40 of Set 10 | flin flon
# Processing Record 41 of Set 10 | sokoto
# Processing Record 42 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | synya
# Processing Record 45 of Set 10 | balkhash
# Processing Record 46 of Set 10 | la ronge
# Processing Record 47 of Set 10 | amudat
# Processing Record 48 of Set 10 | priiskovyy
# Processing Record 49 of Set 10 | manta
# Processing Record 50 of Set 10 | ayan
# Processing Record 1 of Set 11 | siculeni
# Processing Record 2 of Set 11 | norman wells
# Processing Record 3 of Set 11 | funchal
# Processing Record 4 of Set 11 | kailua
# Processing Record 5 of Set 11 | hualmay
# Processing Record 6 of Set 11 | kaeo
# Processing Record 7 of Set 11 | saryozek
# Processing Record 8 of Set 11 | santa fe
# Processing Record 9 of Set 11 | aitape
# Processing Record 10 of Set 11 | te anau
# Processing Record 11 of Set 11 | san quintin
# Processing Record 12 of Set 11 | kaoma
# Processing Record 13 of Set 11 | iquitos
# Processing Record 14 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 11 | pangody
# Processing Record 17 of Set 11 | mineiros
# Processing Record 18 of Set 11 | port augusta
# Processing Record 19 of Set 11 | maniitsoq
# Processing Record 20 of Set 11 | bandarbeyla
# Processing Record 21 of Set 11 | kahului
# Processing Record 22 of Set 11 | mirabad
# Processing Record 23 of Set 11 | pahalgam
# Processing Record 24 of Set 11 | klaksvik
# Processing Record 25 of Set 11 | huambo
# Processing Record 26 of Set 11 | andros
# Processing Record 27 of Set 11 | sotteville-les-rouen
# Processing Record 28 of Set 11 | kochevo
# Processing Record 29 of Set 11 | labuhan
# Processing Record 30 of Set 11 | colon
# Processing Record 31 of Set 11 | dubbo
# Processing Record 32 of Set 11 | roald
# Processing Record 33 of Set 11 | upata
# Processing Record 34 of Set 11 | porto santo
# Processing Record 35 of Set 11 | kailaras
# Processing Record 36 of Set 11 | tilichiki
# Processing Record 37 of Set 11 | setubal
# Processing Record 38 of Set 11 | cherskiy
# Processing Record 39 of Set 11 | namibe
# Processing Record 40 of Set 11 | kirksville
# Processing Record 41 of Set 11 | jubayl
# City not found. Skipping...
# Processing Record 42 of Set 11 | ialibu
# Processing Record 43 of Set 11 | kokkola
# Processing Record 44 of Set 11 | praia da vitoria
# Processing Record 45 of Set 11 | yanam
# Processing Record 46 of Set 11 | pakenham
# Processing Record 47 of Set 11 | puerto escondido
# Processing Record 48 of Set 11 | sistranda
# Processing Record 49 of Set 11 | pudozh
# Processing Record 50 of Set 11 | san francisco
# Processing Record 1 of Set 12 | bilma
# Processing Record 2 of Set 12 | bandar-e lengeh
# Processing Record 3 of Set 12 | juchitan
# City not found. Skipping...
# Processing Record 4 of Set 12 | ruteng
# Processing Record 5 of Set 12 | jacmel
# Processing Record 6 of Set 12 | shitanjing
# Processing Record 7 of Set 12 | boende
# Processing Record 8 of Set 12 | mayo
# Processing Record 9 of Set 12 | benton harbor
# Processing Record 10 of Set 12 | sanary-sur-mer
# Processing Record 11 of Set 12 | urumqi
# Processing Record 12 of Set 12 | laguna
# Processing Record 13 of Set 12 | guarapari
# Processing Record 14 of Set 12 | inhambane
# Processing Record 15 of Set 12 | bambanglipuro
# Processing Record 16 of Set 12 | nueva concepcion
# Processing Record 17 of Set 12 | the valley
# Processing Record 18 of Set 12 | mizdah
# Processing Record 19 of Set 12 | odweyne
# Processing Record 20 of Set 12 | majene
# Processing Record 21 of Set 12 | waiouru
# Processing Record 22 of Set 12 | farah
# Processing Record 23 of Set 12 | pisco
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | hami
# Processing Record 26 of Set 12 | tutoia
# Processing Record 27 of Set 12 | coihueco
# Processing Record 28 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 12 | korla
# Processing Record 30 of Set 12 | samfya
# Processing Record 31 of Set 12 | khilok
# Processing Record 32 of Set 12 | grand gaube
# Processing Record 33 of Set 12 | la roche-sur-yon
# Processing Record 34 of Set 12 | tupancireta
# Processing Record 35 of Set 12 | hobyo
# Processing Record 36 of Set 12 | warrington
# Processing Record 37 of Set 12 | uchiza
# Processing Record 38 of Set 12 | camana
# Processing Record 39 of Set 12 | lincoln
# Processing Record 40 of Set 12 | palana
# Processing Record 41 of Set 12 | richards bay
# Processing Record 42 of Set 12 | amga
# Processing Record 43 of Set 12 | beringovskiy
# Processing Record 44 of Set 12 | wilmington
# Processing Record 45 of Set 12 | muros
# Processing Record 46 of Set 12 | jiuquan
# Processing Record 47 of Set 12 | brandenburg
# Processing Record 48 of Set 12 | almaznyy
# Processing Record 49 of Set 12 | lagos
# Processing Record 50 of Set 12 | payson
# Processing Record 1 of Set 13 | kalininsk
# Processing Record 2 of Set 13 | coylton
# Processing Record 3 of Set 13 | wawa
# Processing Record 4 of Set 13 | teeli
# Processing Record 5 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 13 | merauke
# Processing Record 7 of Set 13 | vila franca do campo
# Processing Record 8 of Set 13 | sabha
# Processing Record 9 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 13 | thinadhoo
# Processing Record 11 of Set 13 | kassala
# Processing Record 12 of Set 13 | port hueneme
# Processing Record 13 of Set 13 | blenheim
# Processing Record 14 of Set 13 | walvis bay
# Processing Record 15 of Set 13 | palora
# Processing Record 16 of Set 13 | natchitoches
# Processing Record 17 of Set 13 | riohacha
# Processing Record 18 of Set 13 | atbasar
# Processing Record 19 of Set 13 | ridgecrest
# Processing Record 20 of Set 13 | mana
# Processing Record 21 of Set 13 | byron bay
# Processing Record 22 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 13 | narathiwat
# Processing Record 24 of Set 13 | batalha
# Processing Record 25 of Set 13 | tazmalt
# Processing Record 26 of Set 13 | montepuez
# Processing Record 27 of Set 13 | yerbogachen
# Processing Record 28 of Set 13 | rognan
# Processing Record 29 of Set 13 | jacareacanga
# Processing Record 30 of Set 13 | asuncion
# Processing Record 31 of Set 13 | yuncheng
# Processing Record 32 of Set 13 | nemuro
# Processing Record 33 of Set 13 | mayumba
# Processing Record 34 of Set 13 | palkino
# Processing Record 35 of Set 13 | atar
# Processing Record 36 of Set 13 | carbonia
# Processing Record 37 of Set 13 | zyryanka
# Processing Record 38 of Set 13 | qinggang
# Processing Record 39 of Set 13 | sola
# Processing Record 40 of Set 13 | trincomalee
# Processing Record 41 of Set 13 | luwuk
# Processing Record 42 of Set 13 | terra santa
# Processing Record 43 of Set 13 | fare
# Processing Record 44 of Set 13 | gamba
# Processing Record 45 of Set 13 | tanete
# Processing Record 46 of Set 13 | newport
# Processing Record 47 of Set 13 | andenes
# Processing Record 48 of Set 13 | sao raimundo nonato
# Processing Record 49 of Set 13 | hambantota
# Processing Record 50 of Set 13 | hachinohe
# Processing Record 1 of Set 14 | teyateyaneng
# Processing Record 2 of Set 14 | trapani
# Processing Record 3 of Set 14 | sioux lookout
# Processing Record 4 of Set 14 | aubenas
# Processing Record 5 of Set 14 | aktau
# Processing Record 6 of Set 14 | karratha
# Processing Record 7 of Set 14 | turgoyak
# Processing Record 8 of Set 14 | mandalgovi
# Processing Record 9 of Set 14 | stende
# Processing Record 10 of Set 14 | mandawar
# Processing Record 11 of Set 14 | ranong
# Processing Record 12 of Set 14 | rosarito
# Processing Record 13 of Set 14 | zhangjiakou
# Processing Record 14 of Set 14 | ewa beach
# Processing Record 15 of Set 14 | bosaso
# Processing Record 16 of Set 14 | caravelas
# Processing Record 17 of Set 14 | broome
# Processing Record 18 of Set 14 | craig
# Processing Record 19 of Set 14 | sembe
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | santa cruz de tenerife
# Processing Record 22 of Set 14 | tres arroyos
# Processing Record 23 of Set 14 | kostomuksha
# Processing Record 24 of Set 14 | lipovtsy
# Processing Record 25 of Set 14 | kapit
# Processing Record 26 of Set 14 | maues
# Processing Record 27 of Set 14 | dawlatabad
# Processing Record 28 of Set 14 | chivay
# Processing Record 29 of Set 14 | esna
# Processing Record 30 of Set 14 | south river
# Processing Record 31 of Set 14 | iguape
# Processing Record 32 of Set 14 | donji milanovac
# Processing Record 33 of Set 14 | murray bridge
# Processing Record 34 of Set 14 | omboue
# Processing Record 35 of Set 14 | barmer
# Processing Record 36 of Set 14 | iberia
# Processing Record 37 of Set 14 | vila
# Processing Record 38 of Set 14 | yumen
# Processing Record 39 of Set 14 | athmallik
# Processing Record 40 of Set 14 | quthing
# Processing Record 41 of Set 14 | tefe
# Processing Record 42 of Set 14 | srednekolymsk
# Processing Record 43 of Set 14 | broken hill
# Processing Record 44 of Set 14 | rundu
# Processing Record 45 of Set 14 | tallahassee
# Processing Record 46 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 14 | solnechnyy
# Processing Record 48 of Set 14 | san juan
# Processing Record 49 of Set 14 | huaral
# Processing Record 50 of Set 14 | benghazi
# Processing Record 1 of Set 15 | oktyabrskoye
# Processing Record 2 of Set 15 | north salt lake
# Processing Record 3 of Set 15 | wanning
# Processing Record 4 of Set 15 | hokitika
# Processing Record 5 of Set 15 | birjand
# Processing Record 6 of Set 15 | luba
# Processing Record 7 of Set 15 | eydhafushi
# Processing Record 8 of Set 15 | aksu
# Processing Record 9 of Set 15 | flinders
# Processing Record 10 of Set 15 | cayenne
# Processing Record 11 of Set 15 | awjilah
# Processing Record 12 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 15 | golubitskaya
# Processing Record 14 of Set 15 | harper
# Processing Record 15 of Set 15 | yar-sale
# Processing Record 16 of Set 15 | manggar
# Processing Record 17 of Set 15 | saint andrews
# Processing Record 18 of Set 15 | karaton
# Processing Record 19 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 15 | tezu
# Processing Record 21 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 15 | bayir
# Processing Record 23 of Set 15 | wasilla
# Processing Record 24 of Set 15 | mancio lima
# Processing Record 25 of Set 15 | bodo
# Processing Record 26 of Set 15 | abong mbang
# Processing Record 27 of Set 15 | makakilo city
# Processing Record 28 of Set 15 | neiafu
# Processing Record 29 of Set 15 | san matias
# Processing Record 30 of Set 15 | katangli
# Processing Record 31 of Set 15 | florina
# Processing Record 32 of Set 15 | novikovo
# Processing Record 33 of Set 15 | collie
# Processing Record 34 of Set 15 | pontianak
# Processing Record 35 of Set 15 | fereydun kenar
# Processing Record 36 of Set 15 | bardiyah
# Processing Record 37 of Set 15 | sao joao da barra
# Processing Record 38 of Set 15 | shujaabad
# Processing Record 39 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 40 of Set 15 | paramonga
# Processing Record 41 of Set 15 | quang ngai
# Processing Record 42 of Set 15 | vozhega
# Processing Record 43 of Set 15 | cozumel
# Processing Record 44 of Set 15 | buala
# Processing Record 45 of Set 15 | deniliquin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Cape Town      ZA  2021-02-01 13:53:04 -33.9258   18.4232     78.80
# 1      Hermanus      ZA  2021-02-01 13:55:22 -34.4187   19.2345     73.00
# 2         Pemba      MZ  2021-02-01 14:01:42 -12.9740   40.5178     86.00
# 3       Ushuaia      AR  2021-02-01 13:55:00 -54.8000  -68.3000     48.20
# 4    Nanortalik      GL  2021-02-01 13:56:07  60.1432  -45.2371     31.46
# ..          ...     ...                  ...      ...       ...       ...
# 691  Quang Ngai      VN  2021-02-01 14:01:24  15.1167  108.8000     67.21
# 692     Vozhega      RU  2021-02-01 14:04:15  60.4725   40.2213     19.71
# 693     Cozumel      MX  2021-02-01 14:04:15  20.5083  -86.9458     75.20
# 694       Buala      SB  2021-02-01 13:56:15  -8.1450  159.5921     81.59
# 695  Deniliquin      AU  2021-02-01 14:04:16 -35.5333  144.9667     60.01
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          36           0       25.32           clear sky
# 1          52           0        8.99           clear sky
# 2          79          20       13.80          few clouds
# 3          76          75       28.77          light rain
# 4          92          99        0.54     overcast clouds
# ..        ...         ...         ...                 ...
# 691        89           0        3.69           clear sky
# 692        97          95        6.98     overcast clouds
# 693        78          20       10.36          few clouds
# 694        81         100       15.48          light rain
# 695        77           0        1.99           clear sky
#
# [696 rows x 10 columns]

# %%
# Create the output file (CSV).
csv_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(csv_data_file, index_label="City_ID")
